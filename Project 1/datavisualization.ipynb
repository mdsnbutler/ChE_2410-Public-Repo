# %%
import pandas as pd
import matplotlib as plt

data = pd.DataFrame(pd.read_csv(r"C:\Users\mdsnb\OneDrive\Documents\GitHub\ChE_2410_Math\Project 1\countydata.csv"))
data.plot(x = 'Density', y = 'Total infections', kind = 'scatter', logx = True, logy = True)
data.plot(x = 'Density', y = 'Public Transportation Usage', kind = 'scatter', logx = True, logy = True)
data.plot(x = 'Public Transportation Usage', y = 'Total infections', kind = 'scatter', logx = True, logy = True)

data.head()
# Out:
#    Unnamed: 0          County    State  Total infections    Density  \
# 0           0  Autauga County  Alabama           2871893  35.853419
# 1           1  Baldwin County  Alabama           9751057  50.541504
# 2           2  Barbour County  Alabama            983791  11.247981
# 3           3     Bibb County  Alabama           1144559  13.973114
# 4           4   Blount County  Alabama           2851498  34.515816
#
#    Public Transportation Usage
# 0                     0.000782
# 1                     0.002143
# 2                     0.003984
# 3                     0.004710
# 4                     0.001639
